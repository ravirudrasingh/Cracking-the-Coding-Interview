# %% [markdown]
# <a href="https://colab.research.google.com/github/ravirudrasingh/Cracking-the-Coding-Interview/blob/master/Market_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Drive Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#### GOOGLE DRIVE SPECIFIC ##########################
# Make sure that you have GPU selected in the Runtime
# If you do, will print Found GPU at: /device:GPU:0
# Else go to Runtime -> Change Runtime Type

import tensorflow as tf
import os
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0

# %%
# CODE SNIPPET TO ACCESS THE FILES IN GOOGLE DRIVE (GO TO BROWSER AND VERIFY)
# THEN YOU CAN ACCESS THE FILES ON LEFT SIDEBAR (copy path)
# (https://colab.research.google.com/drive/1srw_HFWQ2SMgmWIawucXfusGzrj1_U0q#scrollTo=H4SJ-tGNkOeY)

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)
googlepath = "/content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/"

# drive.flush_and_unmount()
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/"
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN
# cnn_models	 companylist.csv.1  logs    stock_data
# companylist.csv  deployed_model     models

# %%
# !rm -rf models
# !rm -rf cnn_models
# !rm -rf deployed_model
# !rm -rf logs

# %%
if not os.path.exists(f'{googlepath}deployed_model'):
            os.makedirs(f'{googlepath}deployed_model')

# %%
# googlepath exists for googledrive finding the files. Can be set to empty 
# string if running on computer. Have companylist.csv in same dir. Will create
# a stock_data folder and download stocks data into that. 

# Setting the Training Amount
TRAINING_AMOUNT = 50000 # low to test for now
SAVE_STEPS_AMOUNT = 10000 # testing for now
PCT_CHANGE_AMOUNT = 5 # just want to see up down trends
HISTORICAL_DAYS_AMOUNT = 20
DAYS_AHEAD = 5

# %% [markdown]
# # Getting the Data
# Currently set to just download stock on first row of companylist.csv (aka AAPL) and saves it to the stock_data folder

# %%
if not os.path.exists(f'{googlepath}companylist.csv'):
            # !wget 'https://raw.githubusercontent.com/kah-ve/MarketGAN/master/companylist.csv'

# %%
'''
Downloads stock data from alphavantage
'''
import pandas as pd 
import os
import time
import urllib
import json
import csv
import requests
import io
from pathlib import Path
import random

ALPHA_VANTAGE_KEY = "5J2PAP7GJNUE8PWE"

'''
Note should have companylist.csv in the directory with this file.
'''

'''
Saves data to a file
'''
def save(googlepath, stock_csv, output_dir, filename):
    try:
        #the output dir may not exist
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
    except Exception as ex:
        print('Could not create output dir')
        print(ex)
        return
    filepath = os.path.join(googlepath, output_dir, filename)
    try:
#         print(stock_csv)
        df = stock_csv
        df = df.sort_values(by='timestamp')  
#         print(df)
        df.to_csv(filepath, index=False)
    except Exception as ex:
        print('Could not open file {} to write data'.format(filepath))
        print(ex)


def try_download(symbol):
    try:
        # Keep call frequency below threshold 
        time.sleep(12)    
        url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}&datatype=csv&outputsize=full'.format(symbol, ALPHA_VANTAGE_KEY)
        c = pd.read_csv(url)
        # getting rid of some columns won't look at for now
        c = c.drop(['split_coefficient', 'dividend_amount', 'adjusted_close'], axis=1)
        return c, True
    except Exception as ex:
        print(ex)
        return None, None



#Given a stock symbol (aka 'tsla') will download and save the data to the
#output dir as a csv 

def download_symbol(symbol, output_dir, retry_count=4):

    stock_csv, didPass = try_download(symbol)
    if didPass:
        save(googlepath, stock_csv, output_dir, '{}.csv'.format(symbol))
    else:
        print('Failed to download {}'.format(symbol))

df = pd.read_csv(f"{googlepath}companylist.csv")
# df = df.sort_values(by=['MarketCap'], ascending=False)
# Top 30 Companies
# df = df[:30]
for symbol in df.Symbol:
    my_file = Path(f"{googlepath}stock_data/{symbol}.csv")  # check if already downloaded
#     print(my_file.exists())
    if not my_file.exists():
        print('Downloading {}'.format(symbol))
        download_symbol(symbol, 'stock_data')
    else:
        print(f"Already downloaded {symbol}")
# Out:
# Already downloaded MMM
# Already downloaded AOS
# Already downloaded ABT
# Already downloaded ABBV
# Already downloaded ACN
# Already downloaded ATVI
# Already downloaded AYI
# Already downloaded ADBE
# Already downloaded AAP
# Already downloaded AMD
# Already downloaded AES
# Already downloaded AET
# Already downloaded AMG
# Already downloaded AFL
# Already downloaded A
# Already downloaded APD
# Already downloaded AKAM
# Already downloaded ALK
# Already downloaded ALB
# Already downloaded ARE
# Already downloaded ALXN
# Already downloaded ALGN
# Already downloaded ALLE
# Already downloaded AGN
# Already downloaded ADS
# Already downloaded LNT
# Already downloaded ALL
# Already downloaded GOOGL
# Already downloaded GOOG
# Already downloaded MO
# Already downloaded AMZN
# Already downloaded AEE
# Already downloaded AAL
# Already downloaded AEP
# Already downloaded AXP
# Already downloaded AIG
# Already downloaded AMT
# Already downloaded AWK
# Already downloaded AMP
# Already downloaded ABC
# Already downloaded AME
# Already downloaded AMGN
# Already downloaded APH
# Already downloaded APC
# Already downloaded ADI
# Already downloaded ANDV
# Already downloaded ANSS
# Already downloaded ANTM
# Already downloaded AON
# Already downloaded APA
# Already downloaded AIV
# Already downloaded AAPL
# Already downloaded AMAT
# Already downloaded APTV
# Already downloaded ADM
# Already downloaded ARNC
# Already downloaded AJG
# Already downloaded AIZ
# Already downloaded T
# Already downloaded ADSK
# Already downloaded ADP
# Already downloaded AZO
# Already downloaded AVB
# Already downloaded AVY
# Already downloaded BHGE
# Already downloaded BLL
# Already downloaded BAC
# Already downloaded BAX
# Already downloaded BBT
# Already downloaded BDX
# Already downloaded BRK.B
# Already downloaded BBY
# Already downloaded BIIB
# Already downloaded BLK
# Already downloaded HRB
# Already downloaded BA
# Already downloaded BKNG
# Already downloaded BWA
# Already downloaded BXP
# Already downloaded BSX
# Already downloaded BHF
# Already downloaded BMY
# Already downloaded AVGO
# Already downloaded CHRW
# Already downloaded CA
# Already downloaded COG
# Already downloaded CDNS
# Already downloaded CPB
# Already downloaded COF
# Already downloaded CAH
# Already downloaded KMX
# Already downloaded CCL
# Already downloaded CAT
# Already downloaded CBOE
# Already downloaded CBRE
# Already downloaded CBS
# Already downloaded CELG
# Already downloaded CNC
# Already downloaded CNP
# Already downloaded CTL
# Already downloaded CERN
# Already downloaded CF
# Already downloaded SCHW
# Already downloaded CHTR
# Already downloaded CVX
# Already downloaded CMG
# Already downloaded CB
# Already downloaded CHD
# Already downloaded CI
# Already downloaded XEC
# Already downloaded CINF
# Already downloaded CTAS
# Already downloaded CSCO
# Already downloaded C
# Already downloaded CFG
# Already downloaded CTXS
# Already downloaded CME
# Already downloaded CMS
# Already downloaded KO
# Already downloaded CTSH
# Already downloaded CL
# Already downloaded CMCSA
# Already downloaded CMA
# Already downloaded CAG
# Already downloaded CXO
# Already downloaded COP
# Already downloaded ED
# Already downloaded STZ
# Already downloaded GLW
# Already downloaded COST
# Already downloaded COTY
# Already downloaded CCI
# Already downloaded CSRA
# Already downloaded CSX
# Already downloaded CMI
# Already downloaded CVS
# Already downloaded DHI
# Already downloaded DHR
# Already downloaded DRI
# Already downloaded DVA
# Already downloaded DE
# Already downloaded DAL
# Already downloaded XRAY
# Already downloaded DVN
# Already downloaded DLR
# Already downloaded DFS
# Already downloaded DISCA
# Already downloaded DISCK
# Already downloaded DISH
# Already downloaded DG
# Already downloaded DLTR
# Already downloaded D
# Already downloaded DOV
# Already downloaded DWDP
# Already downloaded DPS
# Already downloaded DTE
# Already downloaded DUK
# Already downloaded DRE
# Already downloaded DXC
# Already downloaded ETFC
# Already downloaded EMN
# Already downloaded ETN
# Already downloaded EBAY
# Already downloaded ECL
# Already downloaded EIX
# Already downloaded EW
# Already downloaded EA
# Already downloaded EMR
# Already downloaded ETR
# Already downloaded EVHC
# Already downloaded EOG
# Already downloaded EQT
# Already downloaded EFX
# Already downloaded EQIX
# Already downloaded EQR
# Already downloaded ESS
# Already downloaded EL
# Already downloaded RE
# Already downloaded ES
# Already downloaded EXC
# Already downloaded EXPE
# Already downloaded EXPD
# Already downloaded ESRX
# Already downloaded EXR
# Already downloaded XOM
# Already downloaded FFIV
# Already downloaded FB
# Already downloaded FAST
# Already downloaded FRT
# Already downloaded FDX
# Already downloaded FIS
# Already downloaded FITB
# Already downloaded FE
# Already downloaded FISV
# Already downloaded FLIR
# Already downloaded FLS
# Already downloaded FLR
# Already downloaded FMC
# Already downloaded FL
# Already downloaded F
# Already downloaded FTV
# Already downloaded FBHS
# Already downloaded BEN
# Already downloaded FCX
# Already downloaded GPS
# Already downloaded GRMN
# Already downloaded IT
# Already downloaded GD
# Already downloaded GE
# Already downloaded GGP
# Already downloaded GIS
# Already downloaded GM
# Already downloaded GPC
# Already downloaded GILD
# Already downloaded GPN
# Already downloaded GS
# Already downloaded GT
# Already downloaded GWW
# Already downloaded HAL
# Already downloaded HBI
# Already downloaded HOG
# Already downloaded HRS
# Already downloaded HIG
# Already downloaded HAS
# Already downloaded HCA
# Already downloaded HCP
# Already downloaded HP
# Already downloaded HSIC
# Already downloaded HES
# Already downloaded HPE
# Already downloaded HLT
# Already downloaded HOLX
# Already downloaded HD
# Already downloaded HON
# Already downloaded HRL
# Already downloaded HST
# Already downloaded HPQ
# Already downloaded HUM
# Already downloaded HBAN
# Already downloaded HII
# Already downloaded IDXX
# Already downloaded INFO
# Already downloaded ITW
# Already downloaded ILMN
# Already downloaded INCY
# Already downloaded IR
# Already downloaded INTC
# Already downloaded ICE
# Already downloaded IBM
# Already downloaded IP
# Already downloaded IPG
# Already downloaded IFF
# Already downloaded INTU
# Already downloaded ISRG
# Already downloaded IVZ
# Already downloaded IPGP
# Already downloaded IQV
# Already downloaded IRM
# Already downloaded JBHT
# Already downloaded JEC
# Already downloaded SJM
# Already downloaded JNJ
# Already downloaded JCI
# Already downloaded JPM
# Already downloaded JNPR
# Already downloaded KSU
# Already downloaded K
# Already downloaded KEY
# Already downloaded KMB
# Already downloaded KIM
# Already downloaded KMI
# Already downloaded KLAC
# Already downloaded KSS
# Already downloaded KHC
# Already downloaded KR
# Already downloaded LB
# Already downloaded LLL
# Already downloaded LH
# Already downloaded LRCX
# Already downloaded LEG
# Already downloaded LEN
# Already downloaded LUK
# Already downloaded LLY
# Already downloaded LNC
# Already downloaded LKQ
# Already downloaded LMT
# Already downloaded L
# Already downloaded LOW
# Already downloaded LYB
# Already downloaded MTB
# Already downloaded MAC
# Already downloaded M
# Already downloaded MRO
# Already downloaded MPC
# Already downloaded MAR
# Already downloaded MMC
# Already downloaded MLM
# Already downloaded MAS
# Already downloaded MA
# Already downloaded MAT
# Already downloaded MKC
# Already downloaded MCD
# Already downloaded MCK
# Already downloaded MDT
# Already downloaded MRK
# Already downloaded MET
# Already downloaded MTD
# Already downloaded MGM
# Already downloaded KORS
# Already downloaded MCHP
# Already downloaded MU
# Already downloaded MSFT
# Already downloaded MAA
# Already downloaded MHK
# Already downloaded TAP
# Already downloaded MDLZ
# Already downloaded MON
# Already downloaded MNST
# Already downloaded MCO
# Already downloaded MS
# Already downloaded MSI
# Already downloaded MYL
# Already downloaded NDAQ
# Already downloaded NOV
# Already downloaded NAVI
# Already downloaded NKTR
# Already downloaded NTAP
# Already downloaded NFLX
# Already downloaded NWL
# Already downloaded NFX
# Already downloaded NEM
# Already downloaded NWSA
# Already downloaded NWS
# Already downloaded NEE
# Already downloaded NLSN
# Already downloaded NKE
# Already downloaded NI
# Already downloaded NBL
# Already downloaded JWN
# Already downloaded NSC
# Already downloaded NTRS
# Already downloaded NOC
# Already downloaded NCLH
# Already downloaded NRG
# Already downloaded NUE
# Already downloaded NVDA
# Already downloaded ORLY
# Already downloaded OXY
# Already downloaded OMC
# Already downloaded OKE
# Already downloaded ORCL
# Already downloaded PCAR
# Already downloaded PKG
# Already downloaded PH
# Already downloaded PAYX
# Already downloaded PYPL
# Already downloaded PNR
# Already downloaded PBCT
# Already downloaded PEP
# Already downloaded PKI
# Already downloaded PRGO
# Already downloaded PFE
# Already downloaded PCG
# Already downloaded PM
# Already downloaded PSX
# Already downloaded PNW
# Already downloaded PXD
# Already downloaded PNC
# Already downloaded RL
# Already downloaded PPG
# Already downloaded PPL
# Already downloaded PX
# Already downloaded PFG
# Already downloaded PG
# Already downloaded PGR
# Already downloaded PLD
# Already downloaded PRU
# Already downloaded PEG
# Already downloaded PSA
# Already downloaded PHM
# Already downloaded PVH
# Already downloaded QRVO
# Already downloaded QCOM
# Already downloaded PWR
# Already downloaded DGX
# Already downloaded RRC
# Already downloaded RJF
# Already downloaded RTN
# Already downloaded O
# Already downloaded RHT
# Already downloaded REG
# Already downloaded REGN
# Already downloaded RF
# Already downloaded RSG
# Already downloaded RMD
# Already downloaded RHI
# Already downloaded ROK
# Already downloaded COL
# Already downloaded ROP
# Already downloaded ROST
# Already downloaded RCL
# Already downloaded SPGI
# Already downloaded CRM
# Already downloaded SBAC
# Already downloaded SCG
# Already downloaded SLB
# Already downloaded STX
# Already downloaded SEE
# Already downloaded SRE
# Already downloaded SHW
# Already downloaded SPG
# Already downloaded SWKS
# Already downloaded SLG
# Already downloaded SNA
# Already downloaded SO
# Already downloaded LUV
# Already downloaded SWK
# Already downloaded SBUX
# Already downloaded STT
# Already downloaded SRCL
# Already downloaded SYK
# Already downloaded STI
# Already downloaded SIVB
# Already downloaded SYMC
# Already downloaded SYF
# Already downloaded SNPS
# Already downloaded SYY
# Already downloaded TROW
# Already downloaded TTWO
# Already downloaded TPR
# Already downloaded TGT
# Already downloaded TEL
# Already downloaded FTI
# Already downloaded TXN
# Already downloaded TXT
# Already downloaded BK
# Already downloaded CLX
# Already downloaded COO
# Already downloaded HSY
# Already downloaded MOS
# Already downloaded TRV
# Already downloaded DIS
# Already downloaded TMO
# Already downloaded TIF
# Already downloaded TWX
# Already downloaded TJX
# Already downloaded TMK
# Already downloaded TSS
# Already downloaded TSCO
# Already downloaded TDG
# Already downloaded TRIP
# Already downloaded FOXA
# Already downloaded FOX
# Already downloaded TSN
# Already downloaded USB
# Already downloaded UDR
# Already downloaded ULTA
# Already downloaded UAA
# Already downloaded UA
# Already downloaded UNP
# Already downloaded UAL
# Already downloaded UNH
# Already downloaded UPS
# Already downloaded URI
# Already downloaded UTX
# Already downloaded UHS
# Already downloaded UNM
# Already downloaded VFC
# Already downloaded VLO
# Already downloaded VAR
# Already downloaded VTR
# Already downloaded VRSN
# Already downloaded VRSK
# Already downloaded VZ
# Already downloaded VRTX
# Already downloaded VIAB
# Already downloaded V
# Already downloaded VNO
# Already downloaded VMC
# Already downloaded WMT
# Already downloaded WBA
# Already downloaded WM
# Already downloaded WAT
# Already downloaded WEC
# Already downloaded WFC
# Already downloaded WELL
# Already downloaded WDC
# Already downloaded WU
# Already downloaded WRK
# Already downloaded WY
# Already downloaded WHR
# Already downloaded WMB
# Already downloaded WLTW
# Already downloaded WYN
# Already downloaded WYNN
# Already downloaded XEL
# Already downloaded XRX
# Already downloaded XLNX
# Already downloaded XL
# Already downloaded XYL
# Already downloaded YUM
# Already downloaded ZBH
# Already downloaded ZION
# Already downloaded ZTS

# %% [markdown]
# # Helper Functions to Plot: Define the Confusion Matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# # Initializing the GAN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

SEED = 42
tf.set_random_seed(SEED)

class GAN():

    def sample_Z(self, batch_size, n):
        return np.random.uniform(-1., 1., size=(batch_size, n))

    def __init__(self, num_features, num_historical_days, generator_input_size=200, is_train=True):
        def get_batch_norm_with_global_normalization_vars(size):
            v = tf.Variable(tf.ones([size]), dtype=tf.float32)
            m = tf.Variable(tf.ones([size]), dtype=tf.float32)
            beta = tf.Variable(tf.ones([size]), dtype=tf.float32)
            gamma = tf.Variable(tf.ones([size]), dtype=tf.float32)
            return v, m, beta, gamma

        self.X = tf.placeholder(tf.float32, shape=[None, num_historical_days, num_features])
        X = tf.reshape(self.X, [-1, num_historical_days, 1, num_features])
        self.Z = tf.placeholder(tf.float32, shape=[None, generator_input_size])

        generator_output_size = num_features*num_historical_days
        with tf.variable_scope("generator"):
            W1 = tf.Variable(tf.truncated_normal([generator_input_size, generator_output_size*10]))
            b1 = tf.Variable(tf.truncated_normal([generator_output_size*10]))

            h1 = tf.nn.sigmoid(tf.matmul(self.Z, W1) + b1)

            # v1, m1, beta1, gamma1 = get_batch_norm_with_global_normalization_vars(generator_output_size*10)
            # h1 = tf.nn.batch_norm_with_global_normalization(h1, v1, m1,
            #         beta1, gamma1, variance_epsilon=0.000001, scale_after_normalization=False)

            W2 = tf.Variable(tf.truncated_normal([generator_output_size*10, generator_output_size*5]))
            b2 = tf.Variable(tf.truncated_normal([generator_output_size*5]))

            h2 = tf.nn.sigmoid(tf.matmul(h1, W2) + b2)

            # v2, m2, beta2, gamma2 = get_batch_norm_with_global_normalization_vars(generator_output_size*5)
            # h2 = tf.nn.batch_norm_with_global_normalization(h2, v2, m2,
            #         beta2, gamma2, variance_epsilon=0.000001, scale_after_normalization=False)


            W3 = tf.Variable(tf.truncated_normal([generator_output_size*5, generator_output_size]))
            b3 = tf.Variable(tf.truncated_normal([generator_output_size]))

            g_log_prob = tf.matmul(h2, W3) + b3
            g_log_prob = tf.reshape(g_log_prob, [-1, num_historical_days, 1, num_features])
            self.gen_data = tf.reshape(g_log_prob, [-1, num_historical_days, num_features])
            #g_log_prob = g_log_prob / tf.reshape(tf.reduce_max(g_log_prob, axis=1), [-1, 1, num_features, 1])
            #g_prob = tf.nn.sigmoid(g_log_prob)

            theta_G = [W1, b1, W2, b2, W3, b3]



        with tf.variable_scope("discriminator"):
            #[filter_height, filter_width, in_channels, out_channels]
            k1 = tf.Variable(tf.truncated_normal([3, 1, num_features, 32],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b1 = tf.Variable(tf.zeros([32], dtype=tf.float32))

            v1, m1, beta1, gamma1 = get_batch_norm_with_global_normalization_vars(32)

            k2 = tf.Variable(tf.truncated_normal([3, 1, 32, 64],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b2 = tf.Variable(tf.zeros([64], dtype=tf.float32))

            v2, m2, beta2, gamma2 = get_batch_norm_with_global_normalization_vars(64)

            k3 = tf.Variable(tf.truncated_normal([3, 1, 64, 128],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b3 = tf.Variable(tf.zeros([128], dtype=tf.float32))

            v3, m3, beta3, gamma3 = get_batch_norm_with_global_normalization_vars(128)

            W1 = tf.Variable(tf.truncated_normal([18*1*128, 128]))
            b4 = tf.Variable(tf.truncated_normal([128]))

            v4, m4, beta4, gamma4 = get_batch_norm_with_global_normalization_vars(128)

            W2 = tf.Variable(tf.truncated_normal([128, 1]))

            theta_D = [k1, b1, k2, b2, k3, b3, W1, b4, W2]

        def discriminator(X):
            conv = tf.nn.conv2d(X,k1,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b1))
            pool = relu
            # pool = tf.nn.avg_pool(relu, ksize=[1, 2, 1, 1], strides=[1, 2, 1, 1], padding='SAME')
            if is_train:
                pool = tf.nn.dropout(pool, keep_prob = 0.8)
            # pool = tf.nn.batch_norm_with_global_normalization(pool, v1, m1,
            #         beta1, gamma1, variance_epsilon=0.000001, scale_after_normalization=False)
            print(pool)

            conv = tf.nn.conv2d(pool, k2,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b2))
            pool = relu
            #pool = tf.nn.avg_pool(relu, ksize=[1, 2, 1, 1], strides=[1, 2, 1, 1], padding='SAME')
            if is_train:
                pool = tf.nn.dropout(pool, keep_prob = 0.8)
            # pool = tf.nn.batch_norm_with_global_normalization(pool, v2, m2,
            #         beta2, gamma2, variance_epsilon=0.000001, scale_after_normalization=False)
            print(pool)

            conv = tf.nn.conv2d(pool, k3, strides=[1, 1, 1, 1], padding='VALID')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b3))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob=0.8)
            # relu = tf.nn.batch_norm_with_global_normalization(relu, v3, m3,
            #         beta3, gamma3, variance_epsilon=0.000001, scale_after_normalization=False)
            print(relu)


            flattened_convolution_size = int(relu.shape[1]) * int(relu.shape[2]) * int(relu.shape[3])
            print(flattened_convolution_size)
            flattened_convolution = features = tf.reshape(relu, [-1, flattened_convolution_size])

            if is_train:
                flattened_convolution =  tf.nn.dropout(flattened_convolution, keep_prob=0.8)

            h1 = tf.nn.relu(tf.matmul(flattened_convolution, W1) + b4)

            # h1 = tf.nn.batch_norm_with_global_normalization(h1, v4, m4,
            #         beta4, gamma4, variance_epsilon=0.000001, scale_after_normalization=False)

            D_logit = tf.matmul(h1, W2)
            D_prob = tf.nn.sigmoid(D_logit)
            return D_prob, D_logit, features

        D_real, D_logit_real, self.features = discriminator(X)
        D_fake, D_logit_fake, _ = discriminator(g_log_prob)


        D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
        D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
        self.D_l2_loss = (0.0001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_D]) / len(theta_D))
        self.D_loss = D_loss_real + D_loss_fake + self.D_l2_loss
        self.G_l2_loss = (0.00001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_G]) / len(theta_G))
        self.G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake))) + self.G_l2_loss


        self.D_solver = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(self.D_loss, var_list=theta_D)
        self.G_solver = tf.train.AdamOptimizer(learning_rate=0.000055).minimize(self.G_loss, var_list=theta_G)

# %% [markdown]
# # Training the GAN

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf

random.seed(42)
class TrainGan:

    def __init__(self, num_historical_days, batch_size=128):
        self.batch_size = batch_size
        self.data = []
#         files = [os.path.join('./stock_data', f) for f in os.listdir('./stock_data')]

        # Google Drive Method
        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]
#         print(files)
      
        for file in files:
            print(file)
            #Read in file -- note that parse_dates will be need later
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open','high','low','close','volume']]
            # #Create new index with missing days
            # idx = pd.date_range(df.index[-1], df.index[0])
            # #Reindex and fill the missing day with the value from the day before
            # df = df.reindex(idx, method='bfill').sort_index(ascending=False)
            #Normilize using a of size num_historical_days
            df = ((df -
            df.rolling(num_historical_days).mean().shift(-num_historical_days))
            /(df.rolling(num_historical_days).max().shift(-num_historical_days)
            -df.rolling(num_historical_days).min().shift(-num_historical_days)))
            #Drop the last 10 day that we don't have data for
            df = df.dropna()
            #Hold out the last year of trading for testing
            #Padding to keep labels from bleeding
            df = df[400:]
            #This may not create good samples if num_historical_days is a
            #mutliple of 7
            for i in range(num_historical_days, len(df), num_historical_days):
                self.data.append(df.values[i-num_historical_days:i])

        self.gan = GAN(num_features=5, num_historical_days=num_historical_days,
                        generator_input_size=200)

    def random_batch(self, batch_size=128):
        batch = []
        while True:
            batch.append(random.choice(self.data))
            if (len(batch) == batch_size):
                yield batch
                batch = []

    def train(self, print_steps=100, display_data=100, save_steps=SAVE_STEPS_AMOUNT):
        if not os.path.exists(f'{googlepath}models'):
            os.makedirs(f'{googlepath}models')
        sess = tf.Session()
        
        G_loss = 0
        D_loss = 0
        G_l2_loss = 0
        D_l2_loss = 0
        sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver()
        currentStep = "0"
        
        g_loss_array = []
        d_loss_array = []
        
        if os.path.exists(f'{googlepath}models/checkpoint'):
                with open(f'{googlepath}models/checkpoint', 'rb') as f:
                    model_name = next(f).split('"'.encode())[1]
                filename = "{}".format( model_name.decode())
                currentStep = filename.split("-")[1]
                new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                new_saver.restore(sess, "{}".format(filename))

        for i, X in enumerate(self.random_batch(self.batch_size)):

            
            
            
            if i % 1 == 0:
                _, D_loss_curr, D_l2_loss_curr = sess.run([self.gan.D_solver, self.gan.D_loss, self.gan.D_l2_loss], feed_dict=
                        {self.gan.X:X, self.gan.Z:self.gan.sample_Z(self.batch_size, 200)})
                D_loss += D_loss_curr
                D_l2_loss += D_l2_loss_curr
            if i % 1 == 0:
                _, G_loss_curr, G_l2_loss_curr = sess.run([self.gan.G_solver, self.gan.G_loss, self.gan.G_l2_loss],
                        feed_dict={self.gan.Z:self.gan.sample_Z(self.batch_size, 200)})
                G_loss += G_loss_curr
                G_l2_loss += G_l2_loss_curr
                
            g_loss_array.append(G_loss_curr - G_l2_loss)
            d_loss_array.append(D_loss_curr - D_l2_loss)
            
            
            if (i+1) % print_steps == 0:
                print('Step={} D_loss={}, G_loss={}'.format(i + int(currentStep), D_loss/print_steps - D_l2_loss/print_steps, G_loss/print_steps - G_l2_loss/print_steps))
                #print('D_l2_loss = {} G_l2_loss={}'.format(D_l2_loss/print_steps, G_l2_loss/print_steps))
                G_loss = 0
                D_loss = 0
                G_l2_loss = 0
                D_l2_loss = 0
            if (i+1) % save_steps == 0:
                saver.save(sess, f'{googlepath}/models/gan.ckpt', i + int(currentStep))
            
            # end training at training_amount epochs
            if ((i + int(currentStep)) > TRAINING_AMOUNT):
                
                print("Reached {} epochs for GAN".format(i + int(currentStep)))
                sess.close()
                
                axisX = np.arange(0,len(g_loss_array),1)
                plt.plot(axisX, g_loss_array, label='generator loss')
                plt.plot(axisX, d_loss_array, label='discriminator loss')
                plt.legend()
                plt.title('generator and discriminator loss')
                plt.show()
                
                break

            # if (i+1) % display_data == 0:
            #     print('Generated Data')
            #     print(sess.run(self.gan.gen_data, feed_dict={self.gan.Z:self.gan.sample_Z(1, 200)}))
            #     print('Real Data')
            #     print(X[0])


# if __name__ == '__main__':
tf.reset_default_graph()
gan = TrainGan(HISTORICAL_DAYS_AMOUNT, 128)
gan.train()
# Out:
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABBV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ACN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ATVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AYI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADBE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AFL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/A.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AKAM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALLE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOGL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMZN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANDV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANTM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AJG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/T.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AZO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHGE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BRK.B.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BIIB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BKNG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BWA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BMY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHRW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CDNS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CPB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBOE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CELG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CERN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CINF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/C.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTXS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTSH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMCSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CXO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ED.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GLW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COTY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSRA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DFS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/D.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DWDP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DTE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EBAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ECL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EVHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FFIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FAST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FRT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FITB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FISV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLIR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/F.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FBHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GRMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GILD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GWW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSIC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HLT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBAN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HII.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IDXX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INFO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ITW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ILMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INCY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ICE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IBM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IFF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ISRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IVZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IQV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JBHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SJM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNJ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JPM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/K.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KEY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KIM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KLAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LRCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LKQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/L.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LOW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LYB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/M.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MLM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MKC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MGM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KORS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCHP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSFT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MHK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDLZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MNST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NDAQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NAVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NLSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NBL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JWN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NSC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NCLH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NUE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NVDA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OXY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PAYX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PYPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PBCT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PXD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PGR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PLD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PHM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PVH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QRVO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QCOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PWR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DGX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RRC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RJF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RTN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/O.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RSG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPGI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWKS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBUX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SIVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TROW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TTWO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TGT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TIF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TWX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TJX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TDG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRIP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOXA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/USB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UDR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ULTA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/URI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VLO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VIAB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/V.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VNO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WBA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WELL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WDC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WLTW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYNN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XLNX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/YUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZBH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZION.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZTS.csv
# Step=47099 D_loss=0.4859299367666245, G_loss=2.21641833782196
# Step=47199 D_loss=1.1273137408494949, G_loss=1.72647308498621
# Step=47299 D_loss=0.7190636086463928, G_loss=1.9483650866150855
# Step=47399 D_loss=1.0556348052620887, G_loss=1.8566805019974708
# Step=47499 D_loss=1.8963205629587172, G_loss=8.353910385370256
# Step=47599 D_loss=0.1925903484225273, G_loss=11.70187496393919
# Step=47699 D_loss=1.6389080792665482, G_loss=1.7300634601712228
# Step=47799 D_loss=0.7446133077144623, G_loss=1.999680697619915
# Step=47899 D_loss=1.4467969766259192, G_loss=1.4704302647709846
# Step=47999 D_loss=0.5933551931381225, G_loss=1.6796807029843328
# Step=48099 D_loss=0.5819246548414231, G_loss=1.6818017023801806
# Step=48199 D_loss=1.4097422695159914, G_loss=1.8468077716231344
# Step=48299 D_loss=1.0623505273461342, G_loss=1.8550318574905398
# Step=48399 D_loss=0.9965775668621064, G_loss=1.251515354514122
# Step=48499 D_loss=0.9748884829878808, G_loss=1.699011650979519
# Step=48599 D_loss=0.6976382023096085, G_loss=3.1997015699744225
# Step=48699 D_loss=0.8090986821055413, G_loss=5.005686198472977
# Step=48799 D_loss=1.16467638194561, G_loss=1.6261940169334412
# Step=48899 D_loss=1.0215526258945467, G_loss=1.2363214001059533
# Step=48999 D_loss=0.5018830054998398, G_loss=1.8881790325045587
# Step=49099 D_loss=1.0457906970381736, G_loss=1.2482295674085617
# Step=49199 D_loss=0.7536530902981757, G_loss=1.9152932128310203
# Step=49299 D_loss=0.7692480528354644, G_loss=2.4255044823884964
# Step=49399 D_loss=1.3833395010232925, G_loss=1.6203590828180314
# Step=49499 D_loss=0.9760448563098909, G_loss=3.415813243985176
# Step=49599 D_loss=0.17797009080648424, G_loss=12.718725931048393
# Step=49699 D_loss=0.7980124399065971, G_loss=2.334871214032173
# Step=49799 D_loss=0.7682276362180711, G_loss=2.24262190669775
# Step=49899 D_loss=0.6378165096044541, G_loss=2.609842211008072
# Step=49999 D_loss=0.7431040206551554, G_loss=1.8368504679203033
# Reached 50001 epochs for GAN

# %% [markdown]
# # Initializing the CNN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

SEED = 42
tf.set_random_seed(SEED)
class CNN():

    def __init__(self, num_features, num_historical_days, is_train=True):
      
        self.X = tf.placeholder(tf.float32, shape=[None, num_historical_days, num_features])
        X = tf.reshape(self.X, [-1, num_historical_days, 1, num_features])
        self.Y = tf.placeholder(tf.int32, shape=[None, 2])
        self.keep_prob = tf.placeholder(tf.float32, shape=[])

        with tf.variable_scope("cnn"):
            #[filter_height, filter_width, in_channels, out_channels]
            k1 = tf.Variable(tf.truncated_normal([3, 1, num_features, 16],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b1 = tf.Variable(tf.zeros([16], dtype=tf.float32))

            conv = tf.nn.conv2d(X,k1,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b1))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob = self.keep_prob)
            print(relu)


            k2 = tf.Variable(tf.truncated_normal([3, 1, 16, 32],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b2 = tf.Variable(tf.zeros([32], dtype=tf.float32))
            conv = tf.nn.conv2d(relu, k2,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b2))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob = self.keep_prob)
            print(relu)


            k3 = tf.Variable(tf.truncated_normal([3, 1, 32, 64],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b3 = tf.Variable(tf.zeros([64], dtype=tf.float32))
            conv = tf.nn.conv2d(relu, k3, strides=[1, 1, 1, 1], padding='VALID')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b3))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob=self.keep_prob)
            print(relu)


            flattened_convolution_size = int(relu.shape[1]) * int(relu.shape[2]) * int(relu.shape[3])
            print(flattened_convolution_size)
            flattened_convolution = features = tf.reshape(relu, [-1, flattened_convolution_size])

            if is_train:
                flattened_convolution =  tf.nn.dropout(flattened_convolution, keep_prob=self.keep_prob)

            W1 = tf.Variable(tf.truncated_normal([18*1*64, 32]))
            b4 = tf.Variable(tf.truncated_normal([32]))
            h1 = tf.nn.relu(tf.matmul(flattened_convolution, W1) + b4)


            W2 = tf.Variable(tf.truncated_normal([32, 2]))
            logits = tf.matmul(h1, W2)

            #self.accuracy = tf.metrics.accuracy(tf.argmax(self.Y, 1), tf.argmax(logits, 1))
            self.accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(self.Y, 1), tf.argmax(logits, 1)), tf.float32))
            self.confusion_matrix = tf.confusion_matrix(tf.argmax(self.Y, 1), tf.argmax(logits, 1))
            tf.summary.scalar('accuracy', self.accuracy)
            theta_D = [k1, b1, k2, b2, k3, b3, W1, b4, W2]           
            
            # D_prob = tf.nn.sigmoid(D_logit)

        self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=self.Y, logits=logits))
        tf.summary.scalar('loss', self.loss)
        # self.D_l2_loss = (0.0001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_D]) / len(theta_D))
        # self.D_loss = D_loss_real + D_loss_fake + self.D_l2_loss
        # self.G_l2_loss = (0.00001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_G]) / len(theta_G))
        # self.G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake))) + self.G_l2_loss

        self.optimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(self.loss)
        self.summary = tf.summary.merge_all()

# %% [markdown]
# ## Training the CNN

# %%
import os
import pandas as pd
# from cnn import CNN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib
from sklearn.metrics import confusion_matrix
# from plot_confusion_matrix import plot_confusion_matrix

random.seed(42)

class TrainCNN:

    def __init__(self, num_historical_days, days=10, pct_change=0):
        self.data = []
        self.labels = []
        self.test_data = []
        self.test_labels = []
        self.cnn = CNN(num_features=5, num_historical_days=num_historical_days, is_train=False)
#         files = [os.path.join('./stock_data', f) for f in os.listdir('./stock_data')]

        # Google Drive Method
        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]
#         print(files)
    
    
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open','high','low','close','volume']]
            # data for new column labels that will use the pct_change of the closing data.
            # pct_change measure change between current and prior element. Map these into a 1x2
            # array to show if the pct_change > (our desired threshold) or less than.
            labels = df.close.pct_change(days).map(lambda x: [int(x > pct_change/100.0), int(x <= pct_change/100.0)])
            
            # rolling normalization. (df - df.mean) / (df.max - df.min)
            df = ((df -
            df.rolling(num_historical_days).mean().shift(-num_historical_days))
            /(df.rolling(num_historical_days).max().shift(-num_historical_days)
            -df.rolling(num_historical_days).min().shift(-num_historical_days)))
            df['labels'] = labels

            # doing pct_change will give some rows (like first row) a NaN value. Drop that.
            df = df.dropna()

            # Do the testing data split
            test_df = df[:365]
            df = df[400:]

            # get the predictors of the dataframe
            data = df[['open','high','low','close','volume']].values

            # the response value
            labels = df['labels'].values

            # start at num_historical_days and iterate the full length of the training
            # data at intervals of num_historical_days
            for i in range(num_historical_days, len(df), num_historical_days):
                # split the df into arrays of length num_historical_days and append
                # to data, i.e. array of df[curr - num_days : curr] -> a batch of values
                self.data.append(data[i-num_historical_days:i])

                # appending if price went up or down in curr day of "i" we are looking
                # at
                self.labels.append(labels[i-1])
            
            # do same for test data
            data = test_df[['open','high','low','close','volume']].values
            labels = test_df['labels'].values
            for i in range(num_historical_days, len(test_df), 1):
                self.test_data.append(data[i-num_historical_days:i])
                self.test_labels.append(labels[i-1])

    # a function to get a random_batch of data.
    def random_batch(self, batch_size=128):
        batch = []
        labels = []
        # zip concatenates each array index of both arrays together
        data = list(zip(self.data, self.labels))
        i = 0
        while True:
            i+= 1
            while True:
                # pick a random array, i.e. range of days, from data
                d = random.choice(data)
                # balance the data with equal number of positive pct_change
                # and negative pct_change
                if(d[1][0]== int(i%2)):
                    break
            batch.append(d[0])  # append the range of days we got to batch
            labels.append(d[1])  # append the label of that range of data we got
            if (len(batch) == batch_size):
                yield batch, labels
                batch = []
                labels = []

    def train(self, print_steps=100, display_steps=100, save_steps=SAVE_STEPS_AMOUNT, batch_size=128, keep_prob=0.6):
        if not os.path.exists(f'{googlepath}cnn_models'):
            os.makedirs(f'{googlepath}cnn_models')
        if not os.path.exists(f'{googlepath}logs'):
            os.makedirs(f'{googlepath}logs')
        if os.path.exists(f'{googlepath}logs/train'):
            for file in [os.path.join(f'{googlepath}logs/train/', f) for f in os.listdir(f'{googlepath}logs/train/')]:
                os.remove(file)
        if os.path.exists(f'{googlepath}logs/test'):
            for file in [os.path.join(f'{googlepath}logs/test/', f) for f in os.listdir(f'{googlepath}logs/test')]:
                os.remove(file)

        sess = tf.Session()
        loss = 0
        l2_loss = 0
        accuracy = 0
        saver = tf.train.Saver()
        train_writer = tf.summary.FileWriter(f'{googlepath}/logs/train')
        test_writer = tf.summary.FileWriter(f'{googlepath}/logs/test')
        sess.run(tf.global_variables_initializer())
        
        test_loss_array = []
        test_accuracy_array = []
        currentStep = "0"
        plt_cnf = False if os.path.exists(f'{googlepath}cnn_models/checkpoint') else True
        if os.path.exists(f'{googlepath}cnn_models/checkpoint'):
                with open(f'{googlepath}cnn_models/checkpoint', 'rb') as f:
                    model_name = next(f).split('"'.encode())[1]
                filename = "{}".format( model_name.decode())
                currentStep = filename.split("-")[1]
                new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                new_saver.restore(sess, "{}".format(filename))

        for i, [X, y] in enumerate(self.random_batch(batch_size)):

          
            _, loss_curr, accuracy_curr = sess.run([self.cnn.optimizer, self.cnn.loss, self.cnn.accuracy], feed_dict=
                    {self.cnn.X:X, self.cnn.Y:y, self.cnn.keep_prob:keep_prob})
            loss += loss_curr
            accuracy += accuracy_curr
            if (i+1) % print_steps == 0:
                print('Step={} loss={}, accuracy={}'.format(i + int(currentStep), loss/print_steps, accuracy/print_steps))
                loss = 0
                l2_loss = 0
                accuracy = 0
                test_loss, test_accuracy, confusion_matrix = sess.run([self.cnn.loss, self.cnn.accuracy, self.cnn.confusion_matrix], feed_dict={self.cnn.X:self.test_data, self.cnn.Y:self.test_labels, self.cnn.keep_prob:1})
                test_loss_array.append(test_loss)
                test_accuracy_array.append(test_accuracy)
                print("Test loss = {}, Test accuracy = {}".format(test_loss, test_accuracy))
            if (i+1) % save_steps == 0:
                saver.save(sess,  f'{googlepath}cnn_models/cnn.ckpt', i)

            if (i+1) % display_steps == 0:
                summary = sess.run(self.cnn.summary, feed_dict=
                    {self.cnn.X:X, self.cnn.Y:y, self.cnn.keep_prob:keep_prob})
                train_writer.add_summary(summary, i)
                summary = sess.run(self.cnn.summary, feed_dict={
                    self.cnn.X:self.test_data, self.cnn.Y:self.test_labels, self.cnn.keep_prob:1})
                test_writer.add_summary(summary, i)
            
            # end training at training_amount epochs
            if (i + int(currentStep)) > TRAINING_AMOUNT:
                print("Reached {} epochs for CNN".format(i + int(currentStep)))
                sess.close()
                if plt_cnf:
                  print(confusion_matrix)
                  plot_confusion_matrix(confusion_matrix, ['Down', 'Up'], normalize=True, title="CNN Confusion Matrix")
                
                axisX = np.arange(0,len(test_loss_array),1)
                plt.plot(axisX, test_loss_array, label='test loss')
                plt.plot(axisX, test_accuracy_array, label='test accuracy')
                plt.legend()
                plt.title('test loss and accuracy')
                plt.show()

                break


# if __name__ == '__main__':
tf.reset_default_graph()
cnn = TrainCNN(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
cnn.train()
# print(confusion_matrix)
# Out:
# Tensor("cnn/Relu:0", shape=(?, 20, 1, 16), dtype=float32)
# Tensor("cnn/Relu_1:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("cnn/Relu_2:0", shape=(?, 18, 1, 64), dtype=float32)
# 1152
# WARNING:tensorflow:From <ipython-input-13-3ac5478d33d2>:73: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABBV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ACN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ATVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AYI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADBE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AFL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/A.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AKAM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALLE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOGL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMZN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANDV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANTM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AJG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/T.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AZO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHGE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BRK.B.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BIIB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BKNG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BWA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BMY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHRW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CDNS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CPB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBOE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CELG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CERN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CINF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/C.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTXS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTSH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMCSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CXO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ED.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GLW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COTY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSRA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DFS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/D.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DWDP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DTE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EBAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ECL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EVHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FFIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FAST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FRT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FITB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FISV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLIR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/F.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FBHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GRMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GILD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GWW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSIC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HLT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBAN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HII.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IDXX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INFO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ITW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ILMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INCY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ICE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IBM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IFF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ISRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IVZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IQV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JBHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SJM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNJ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JPM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/K.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KEY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KIM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KLAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LRCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LKQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/L.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LOW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LYB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/M.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MLM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MKC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MGM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KORS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCHP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSFT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MHK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDLZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MNST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NDAQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NAVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NLSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NBL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JWN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NSC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NCLH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NUE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NVDA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OXY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PAYX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PYPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PBCT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PXD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PGR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PLD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PHM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PVH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QRVO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QCOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PWR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DGX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RRC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RJF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RTN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/O.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RSG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPGI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWKS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBUX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SIVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TROW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TTWO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TGT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TIF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TWX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TJX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TDG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRIP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOXA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/USB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UDR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ULTA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/URI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VLO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VIAB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/V.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VNO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WBA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WELL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WDC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WLTW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYNN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XLNX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/YUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZBH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZION.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZTS.csv
# Step=99 loss=0.6306632310152054, accuracy=0.710234375
# Test loss = 0.49137431383132935, Test accuracy = 0.7759197950363159
# Step=199 loss=0.4720116353034973, accuracy=0.784296875
# Test loss = 0.41133615374565125, Test accuracy = 0.8172485828399658
# Step=299 loss=0.42268060982227323, accuracy=0.8128125
# Test loss = 0.386813759803772, Test accuracy = 0.8274856209754944
# Step=399 loss=0.3951673984527588, accuracy=0.817890625
# Test loss = 0.35592392086982727, Test accuracy = 0.8438211679458618
# Step=499 loss=0.37387282371520997, accuracy=0.83359375
# Test loss = 0.322532057762146, Test accuracy = 0.8582891225814819
# Step=599 loss=0.3607084894180298, accuracy=0.84125
# Test loss = 0.31709024310112, Test accuracy = 0.8599895238876343
# Step=699 loss=0.34974687948822974, accuracy=0.848359375
# Test loss = 0.31119731068611145, Test accuracy = 0.8629003763198853
# Step=799 loss=0.3388705772161484, accuracy=0.851484375
# Test loss = 0.3109991252422333, Test accuracy = 0.8629234433174133
# Step=899 loss=0.33715523332357406, accuracy=0.852734375
# Test loss = 0.29262688755989075, Test accuracy = 0.8717425465583801
# Step=999 loss=0.33069292187690735, accuracy=0.853125
# Test loss = 0.28350549936294556, Test accuracy = 0.8946260809898376
# Step=48799 loss=0.17724052101373672, accuracy=0.936171875
# Test loss = 0.2812952697277069, Test accuracy = 0.8943609595298767
# Step=48899 loss=0.17440255396068097, accuracy=0.935859375
# Test loss = 0.2843822240829468, Test accuracy = 0.8930121660232544
# Step=48999 loss=0.1785713993012905, accuracy=0.935
# Test loss = 0.2796894907951355, Test accuracy = 0.8937095999717712
# Step=49099 loss=0.17463802352547644, accuracy=0.9328125
# Test loss = 0.2865748703479767, Test accuracy = 0.8939632177352905
# Step=49199 loss=0.1753660461306572, accuracy=0.938125
# Test loss = 0.28610897064208984, Test accuracy = 0.8931043744087219
# Step=49299 loss=0.17452927470207213, accuracy=0.936796875
# Test loss = 0.287325382232666, Test accuracy = 0.8943033218383789
# Step=49399 loss=0.17481918655335904, accuracy=0.935390625
# Test loss = 0.281095415353775, Test accuracy = 0.8947702050209045
# Step=49499 loss=0.17504907965660096, accuracy=0.935234375
# Test loss = 0.28101104497909546, Test accuracy = 0.893997848033905
# Step=49599 loss=0.1756599135696888, accuracy=0.933359375
# Test loss = 0.2784838378429413, Test accuracy = 0.8944416642189026
# Step=49699 loss=0.1722999031096697, accuracy=0.93765625
# Test loss = 0.2795282304286957, Test accuracy = 0.894389808177948
# Step=49799 loss=0.17361477933824063, accuracy=0.93546875
# Test loss = 0.28319358825683594, Test accuracy = 0.8941246271133423
# Step=49899 loss=0.1716924738138914, accuracy=0.93328125
# Test loss = 0.28790074586868286, Test accuracy = 0.8950123190879822
# Step=49999 loss=0.17213602147996426, accuracy=0.936796875
# Test loss = 0.28025132417678833, Test accuracy = 0.8948451280593872
# Reached 50001 epochs for CNN
# [[ 23519  10432]
#  [  7811 131725]]
# Normalized confusion matrix
# [[0.69273365 0.30726635]
#  [0.05597839 0.94402161]]

# %% [markdown]
# # Train XGB Boost

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib
from sklearn.metrics import confusion_matrix
# from plot_confusion_matrix import plot_confusion_matrix

# os.environ["CUDA_VISIBLE_DEVICES"]=""

class TrainXGBBoost:

    def __init__(self, num_historical_days, days=10, pct_change=0):
        self.data = []
        self.labels = []
        self.test_data = []
        self.test_labels = []
        
        assert os.path.exists(f'{googlepath}models/checkpoint')
        gan = GAN(num_features=5, num_historical_days=num_historical_days,
                        generator_input_size=200, is_train=False)
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            if os.path.exists(f'{googlepath}models/checkpoint'):
                    
                    with open(f'{googlepath}models/checkpoint', 'rb') as f:
                        model_name = next(f).split('"'.encode())[1]
                    filename = "{}".format( model_name.decode())
                    currentStep = filename.split("-")[1]
                    new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                    new_saver.restore(sess, "{}".format(filename))
            files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}/stock_data')]
            for file in files:
                print(file)
                #Read in file -- note that parse_dates will be need later
                df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
                df = df[['open','high','low','close','volume']]
                # #Create new index with missing days
                # idx = pd.date_range(df.index[-1], df.index[0])
                # #Reindex and fill the missing day with the value from the day before
                # df = df.reindex(idx, method='bfill').sort_index(ascending=False)
                #Normilize using a of size num_historical_days
                labels = df.close.pct_change(days).map(lambda x: int(x > pct_change/100.0))
                df = ((df -
                df.rolling(num_historical_days).mean().shift(-num_historical_days))
                /(df.rolling(num_historical_days).max().shift(-num_historical_days)
                -df.rolling(num_historical_days).min().shift(-num_historical_days)))
                df['labels'] = labels
                #Drop the last 10 day that we don't have data for
                df = df.dropna()
                #Hold out the last year of trading for testing
                test_df = df[:365]
                #Padding to keep labels from bleeding
                df = df[400:]
                #This may not create good samples if num_historical_days is a
                #mutliple of 7
                data = df[['open','high','low','close','volume']].values
                labels = df['labels'].values
                for i in range(num_historical_days, len(df), num_historical_days):
                    features = sess.run(gan.features, feed_dict={gan.X:[data[i-num_historical_days:i]]})
                    self.data.append(features[0])
#                     print(features[0])
                    self.labels.append(labels[i-1])
                data = test_df[['open','high','low','close','volume']].values
                labels = test_df['labels'].values
                for i in range(num_historical_days, len(test_df), 1):
                    features = sess.run(gan.features, feed_dict={gan.X:[data[i-num_historical_days:i]]})
                    self.test_data.append(features[0])
                    self.test_labels.append(labels[i-1])



    def train(self):
        params = {}
        params['objective'] = 'multi:softprob'
        params['eta'] = 0.01
        params['num_class'] = 2
        params['max_depth'] = 20
        params['subsample'] = 0.05
        params['colsample_bytree'] = 0.05
        params['eval_metric'] = 'mlogloss'
        #params['scale_pos_weight'] = 10
        #params['silent'] = True
        #params['gpu_id'] = 0
        #params['max_bin'] = 16
        #params['tree_method'] = 'gpu_hist'

        train = xgb.DMatrix(self.data, self.labels)
        test = xgb.DMatrix(self.test_data, self.test_labels)

        watchlist = [(train, 'train'), (test, 'test')]
        clf = xgb.train(params, train, 1000, evals=watchlist, early_stopping_rounds=100)
        joblib.dump(clf, f'{googlepath}models/clf.pkl')
        # cm = confusion_matrix(self.test_labels, map(lambda x: int(x[1] > .5), clf.predict(test)))
        cm = confusion_matrix(self.test_labels, list(map(lambda x: int(x[1] > .5), clf.predict(test))))
        print(cm)
        plot_confusion_matrix(cm, ['Down', 'Up'], normalize=True, title="Confusion Matrix")

tf.reset_default_graph()
boost_model = TrainXGBBoost(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
boost_model.train()
# Out:
# Tensor("Relu:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# Tensor("Relu_4:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_5:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_6:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN//models/gan.ckpt-49999
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABBV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ACN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ATVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AYI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADBE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AFL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/A.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AKAM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALLE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOGL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMZN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANDV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANTM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AJG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/T.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AZO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHGE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BRK.B.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BIIB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BKNG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BWA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BMY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHRW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CDNS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CPB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBOE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CELG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CERN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CINF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/C.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTXS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTSH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMCSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CXO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ED.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GLW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COTY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSRA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DFS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/D.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DWDP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DTE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EBAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ECL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EVHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FFIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FAST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FRT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FITB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FISV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLIR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/F.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FBHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GRMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GILD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GWW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSIC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HLT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBAN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HII.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IDXX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INFO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ITW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ILMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INCY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ICE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IBM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IFF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ISRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IVZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IQV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JBHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SJM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNJ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JPM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/K.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KEY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KIM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KLAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LRCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LKQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/L.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LOW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LYB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/M.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MLM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MKC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MGM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KORS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCHP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSFT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MHK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDLZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MNST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NDAQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NAVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NLSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NBL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JWN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NSC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NCLH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NUE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NVDA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OXY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PAYX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PYPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PBCT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PXD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PGR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PLD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PHM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PVH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QRVO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QCOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PWR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DGX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RRC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RJF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RTN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/O.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RSG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPGI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWKS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBUX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SIVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TROW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TTWO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TGT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TIF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TWX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TJX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TDG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRIP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOXA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/USB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UDR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ULTA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/URI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VLO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VIAB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/V.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VNO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WBA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WELL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WDC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WLTW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYNN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XLNX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/YUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZBH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZION.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZTS.csv
# [0]	train-mlogloss:0.685969	test-mlogloss:0.687222
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.67894	test-mlogloss:0.68143
# [2]	train-mlogloss:0.672084	test-mlogloss:0.675808
# [3]	train-mlogloss:0.665368	test-mlogloss:0.670283
# [4]	train-mlogloss:0.658671	test-mlogloss:0.664781
# [5]	train-mlogloss:0.652141	test-mlogloss:0.659446
# [6]	train-mlogloss:0.645679	test-mlogloss:0.654209
# [7]	train-mlogloss:0.639409	test-mlogloss:0.649125
# [8]	train-mlogloss:0.633381	test-mlogloss:0.644334
# [304]	train-mlogloss:0.193451	test-mlogloss:0.38766
# [305]	train-mlogloss:0.193214	test-mlogloss:0.387759
# [306]	train-mlogloss:0.192987	test-mlogloss:0.387893
# [307]	train-mlogloss:0.192742	test-mlogloss:0.387914
# [308]	train-mlogloss:0.192526	test-mlogloss:0.388023
# [309]	train-mlogloss:0.192333	test-mlogloss:0.388203
# [310]	train-mlogloss:0.192074	test-mlogloss:0.388218
# [311]	train-mlogloss:0.191866	test-mlogloss:0.388371
# [312]	train-mlogloss:0.191659	test-mlogloss:0.388504
# [313]	train-mlogloss:0.191461	test-mlogloss:0.388628
# [314]	train-mlogloss:0.191232	test-mlogloss:0.388709
# [315]	train-mlogloss:0.191006	test-mlogloss:0.388807
# [316]	train-mlogloss:0.190757	test-mlogloss:0.388902
# [317]	train-mlogloss:0.190562	test-mlogloss:0.389063
# Stopping. Best iteration:
# [217]	train-mlogloss:0.223267	test-mlogloss:0.383318
#
# [[139139    397]
#  [ 29884   4067]]
# Normalized confusion matrix
# [[0.99715486 0.00284514]
#  [0.88020971 0.11979029]]

# %% [markdown]
# ## Change the names of the files in the deployed_model folder
#
# Directions: Run after training and placing the GAN checkpoints you desire into the deployed_models folder. Then thisd code will rename all of them so that they run for the "Get the Predictions" section.

# %%
from shutil import copyfile

# copyfile(src, dst)

import os

# Below Code Gets Rid of Copy Of when making a copy of the models.
for filename in os.listdir(f'{googlepath}cnn_models/'):
    copyfile(f'{googlepath}cnn_models/{filename}', f'{googlepath}deployed_model/{filename}')

# Below Code Gets Rid of Checkpoint Number in Name
for filename in os.listdir(f'{googlepath}models/'):
    copyfile(f'{googlepath}models/{filename}', f'{googlepath}deployed_model/{filename}')

# %%
import os

# Below Code Gets Rid of Copy Of when making a copy of the models.
for filename in os.listdir(f'{googlepath}deployed_model/'):
    split = filename.split(" ")
    if len(split) == 3:
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/{split[2]}')
    else:
        print("Nothing to rename.")

# Below Code Gets Rid of Checkpoint Number in Name
for filename in os.listdir(f'{googlepath}deployed_model/'):
    split = filename.split(".")
    if len(split) == 3:
        prefix, _, suffix = split
        new_name = prefix + "." + suffix
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/{new_name}')
    elif filename == "clf.pkl":
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/xgb')
    else:
        print("Nothing to rename.")
# Out:
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.

# %% [markdown]
# # Get the Predictions

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib


# os.environ["CUDA_VISIBLE_DEVICES"]=""

class Predict:

    def __init__(self, num_historical_days=20, days=10, pct_change=0, 
                 gan_model=f'{googlepath}deployed_model/gan', 
                 cnn_model=f'{googlepath}deployed_model/cnn', 
                 xgb_model=f'{googlepath}deployed_model/xgb'):
        self.data = []
        self.num_historical_days = num_historical_days
        self.gan_model = gan_model
        self.cnn_model = cnn_model
        self.xgb_model = xgb_model
        # assert os.path.exists(gan_model)
        # assert os.path.exists(cnn_modle)
        # assert os.path.exists(xgb_model)

        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df.sort_index(ascending=False)
            df = df[['open', 'high', 'low', 'close', 'volume']]
            df = ((df -
                  df.rolling(num_historical_days).mean().shift(-num_historical_days)) /
                  (df.rolling(num_historical_days).max().shift(-num_historical_days) -
                  df.rolling(num_historical_days).min().shift(-num_historical_days)))
            df = df.dropna()

            """
            file.split --> is the symbol of the current file. Append a tuple of
            that symbol and the dataframe index[0] which is the timestamp, and
            thirdly append the data for 200 to 200 + num_historical_days values
            (open, high, low, close, volume). For each symbol we have, we are
            predicting based on the df[200:200+num_historical_days].values...
            """
            self.data.append((file.split('/')[-1], df.index[0], df[200:200+num_historical_days].values))
            
#         print("Data: ", self.data)


    def gan_predict(self):
        # clears the default graph stack and resets the global default graph.
        try:
          tf.reset_default_graph() 
          gan = GAN(num_features=5, num_historical_days=self.num_historical_days,
                    generator_input_size=200, is_train=False)
          # A class for running Tensorflow operations. A session object
          # encapsulates the environment in which Operation objects are executed,
          # and Tensor objects are evaluated. A session may own resources, such as
          # tf.Variable, tf.QueueBase and tf.ReaderBase. It is important to
          # release these resources when they are no longer required. Invoke
          # tf.Session.close method on the session or use the session as a context
          # manager. 
          # with tf.Session() as sess:
          #   sess.run(...)
          # or
          # sess = tf.Session()
          # sess.run(...)
          # sess.close()     
          with tf.Session() as sess:
              sess.run(tf.global_variables_initializer())
              saver = tf.train.Saver()
              saver.restore(sess, self.gan_model)
              # Reconstruct a Python object from a file persisted with joblib.dump
              clf = joblib.load(self.xgb_model)
              for sym, date, data in self.data:
                  # run takes in feed_dict=None, session=None. A feed_dict is a
                  # dictionary that maps Tensor objects to feed values. In this
                  # case, I believe we are doing run( fetches, feed_dict=None...)
                  # case where the fetches is gan.features and the feed_dict
                  # points to the gan.X dictionary which points to data. The
                  # fetches argument may be a single graph element, or an
                  # arbitrarily nested list, tuple, namedtuple, dict, or
                  # OrderedDict containing graph elements at its leaves.
  #                 print("data: ", data)
  #                 print("data length: ", len(data))
  #                 print("gan features: ", gan.features)
                  features = sess.run(gan.features, feed_dict={gan.X:[data]})
                  # Value returned by run() has the same shape as the fetches
                  # argument, where the leaves are replaced by the corresponding
                  # values returned by TensorFlow.  
                  
                  # xgb.DMatrix, construct one from either a dense matrix, a
                  # sparse matrix, or a local file. Supported input file formats
                  # are either a libsvm text file or a binary file that was
                  # created previously by xgb.DMatrix.save. Internal data
                  # structure that is used by XGBoost which is optimized for both
                  # memory efficiency and training speed.
                  features = xgb.DMatrix(features)
                  

                  # The clf predict is the xgb classifier that is used on the gan
                  # features (the flattened last layer of the convolutional neural
                  # network, that is the discriminator). As far as I can tell, we
                  # are using the GAN on the past 20 days to come up with some
                  # features. Then these features are plugged into the XGBoost
                  # Classifier. Then the XGBoost Classifier makes a prediction for
                  # the stock (going Up or Down).
                  print('{} {} {}'.format(str(date).split(' ')[0], sym, clf.predict(features)[0][1] > 0.5))

        except Exception as e:
          print(sym," : ",e)
# if __name__ == '__main__':
p = Predict(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
p.gan_predict()
# Out:
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABBV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ACN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ATVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AYI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADBE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AFL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/A.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AKAM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALLE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ALL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOGL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GOOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMZN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ABC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANDV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ANTM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AAPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AMAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/APTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ARNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AJG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AIZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/T.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ADP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AZO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHGE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BAX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BRK.B.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BBY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BIIB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BLK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BKNG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BWA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BXP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BHF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BMY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/AVGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHRW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CDNS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CPB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBOE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CBS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CELG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CERN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CHD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CINF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/C.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTXS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CME.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CTSH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMCSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CAG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CXO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ED.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GLW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COTY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSRA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CVS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DVN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DFS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DISH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DLTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/D.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DWDP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DTE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EBAY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ECL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EMR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ETR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EVHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQIX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EQR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXPD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ESRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/EXR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FFIV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FAST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FRT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FDX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FITB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FISV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLIR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FLR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/F.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FBHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GRMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GILD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GPN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/GWW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HIG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HCP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSIC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HES.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HLT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HOLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HRL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HPQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HBAN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HII.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IDXX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INFO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ITW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ILMN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INCY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ICE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IBM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IFF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/INTU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ISRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IVZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IPGP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IQV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/IRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JBHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SJM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNJ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JCI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JPM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JNPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/K.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KEY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KIM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KMI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KLAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KHC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LRCX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LEN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LKQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/L.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LOW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LYB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/M.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MPC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MLM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MKC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MET.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MTD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MGM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/KORS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCHP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSFT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MHK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MDLZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MON.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MNST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MSI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NDAQ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NAVI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTAP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NFX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NWS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NLSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NBL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/JWN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NSC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NTRS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NOC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NCLH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NRG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NUE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/NVDA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORLY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OXY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/OKE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ORCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PAYX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PYPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PBCT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PKI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRGO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PXD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PNC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PPL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PFG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PGR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PLD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PRU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PEG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PSA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PHM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PVH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QRVO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/QCOM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/PWR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DGX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RRC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RJF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RTN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/O.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/REGN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RSG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RMD.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RHI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ROST.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/RCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPGI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CRM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBAC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SCG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SEE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRE.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SHW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SPG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWKS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SLG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/LUV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SWK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SBUX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SRCL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/STI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SIVB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SNPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/SYY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TROW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TTWO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TPR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TGT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FTI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TXT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/BK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/CLX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/COO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/HSY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/MOS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRV.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/DIS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TIF.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TWX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TJX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TMK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSCO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TDG.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TRIP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOXA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/FOX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/TSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/USB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UDR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ULTA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNP.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UAL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UPS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/URI.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UHS.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/UNM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VLO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VAR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VTR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRSK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VZ.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VRTX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VIAB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/V.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VNO.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/VMC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WBA.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WAT.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WEC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WFC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WELL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WDC.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WU.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WRK.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WY.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WHR.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WMB.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WLTW.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/WYNN.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XEL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XRX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XLNX.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/XYL.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/YUM.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZBH.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZION.csv
# /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/stock_data/ZTS.csv
# Tensor("Relu:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# Tensor("Relu_4:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_5:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_6:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/SeniorDesignGAN/MiloGAN/deployed_model/gan
# 2019-12-06 MMM.csv False
# 2019-12-06 AOS.csv False
# 2019-12-06 ABT.csv False
# 2019-12-06 ABBV.csv True
# 2019-12-06 ACN.csv False
# 2019-12-06 ATVI.csv True
# 2019-12-06 AYI.csv False
# 2019-12-06 ADBE.csv False
# 2019-12-06 AAP.csv True
# 2019-12-06 AMD.csv False
# 2019-12-06 AES.csv False
# 2018-11-28 AET.csv False
# 2019-12-06 AMG.csv True
# 2019-12-06 AFL.csv False
# 2019-12-06 A.csv False
# 2019-12-06 APD.csv False
# 2019-12-06 AKAM.csv False
# 2019-12-06 ALK.csv True
# 2019-12-06 ALB.csv False
# 2019-12-06 ARE.csv False
# 2019-12-06 ALXN.csv True
# 2019-12-06 ALGN.csv False
# 2019-12-06 ALLE.csv False
# 2019-12-06 AGN.csv True
# 2019-12-06 ADS.csv True
# 2019-12-06 LNT.csv False
# 2019-12-06 ALL.csv False
# 2019-12-06 GOOGL.csv True
# 2019-12-06 GOOG.csv True
# 2019-12-06 MO.csv True
# 2019-12-06 AMZN.csv True
# 2019-12-06 AEE.csv True
# 2019-12-06 AAL.csv True
# 2019-12-06 AEP.csv False
# 2019-12-06 AXP.csv False
# 2019-12-06 AIG.csv True
# 2019-12-06 AMT.csv False
# 2019-12-06 AWK.csv False
# 2019-12-06 AMP.csv False
# 2019-12-06 ABC.csv False
# 2019-12-06 AME.csv False
# 2019-12-06 AMGN.csv True
# 2019-12-06 APH.csv False
# 2019-08-08 APC.csv False
# 2019-12-06 ADI.csv False
# 2018-09-28 ANDV.csv True
# 2019-12-06 ANSS.csv False
# 2019-12-06 ANTM.csv False
# 2019-12-06 AON.csv False
# 2019-12-06 APA.csv True
# 2019-12-06 AIV.csv False
# 2019-12-06 AAPL.csv False
# 2019-12-06 AMAT.csv False
# 2019-12-06 APTV.csv False
# 2019-12-06 ADM.csv True
# 2019-12-06 ARNC.csv True
# 2019-12-06 AJG.csv False
# 2019-12-06 AIZ.csv False
# 2019-12-06 T.csv True
# 2019-12-06 ADSK.csv False
# 2019-12-06 ADP.csv False
# 2019-12-06 AZO.csv False
# 2019-12-06 AVB.csv False
# 2019-12-06 AVY.csv False
# 2019-12-06 BHGE.csv False
# 2019-12-06 BLL.csv False
# 2019-12-06 BAC.csv True
# 2019-12-06 BAX.csv True
# 2019-12-06 BBT.csv True
# 2019-12-06 BDX.csv True
# 2019-12-06 BRK.B.csv True
# 2019-12-06 BBY.csv True
# 2019-12-06 BIIB.csv True
# 2019-12-06 BLK.csv True
# 2019-12-06 HRB.csv True
# 2019-12-06 BA.csv False
# 2019-12-06 BKNG.csv False
# 2019-12-06 BWA.csv True
# 2019-12-06 BXP.csv False
# 2019-12-06 BSX.csv False
# 2019-12-06 BHF.csv True
# 2019-12-06 BMY.csv True
# 2019-12-06 AVGO.csv False
# 2019-12-06 CHRW.csv True
# 2018-11-06 CA.csv True
# 2019-12-06 COG.csv True
# 2019-12-06 CDNS.csv False
# 2019-12-06 CPB.csv True
# 2019-12-06 COF.csv True
# 2019-12-06 CAH.csv False
# 2019-12-06 KMX.csv True
# 2019-12-06 CCL.csv True
# 2019-12-06 CAT.csv True
# 2019-12-06 CBOE.csv True
# 2019-12-06 CBRE.csv False
# 2019-12-04 CBS.csv True
# 2019-11-22 CELG.csv True
# 2019-12-06 CNC.csv True
# 2019-12-06 CNP.csv False
# 2019-12-06 CTL.csv True
# 2019-12-06 CERN.csv True
# 2019-12-06 CF.csv True
# 2019-12-06 SCHW.csv True
# 2019-12-06 CHTR.csv False
# 2019-12-06 CVX.csv False
# 2019-12-06 CMG.csv True
# 2019-12-06 CB.csv True
# 2019-12-06 CHD.csv True
# 2019-12-06 CI.csv True
# 2019-12-06 XEC.csv True
# 2019-12-06 CINF.csv False
# 2019-12-06 CTAS.csv False
# 2019-12-06 CSCO.csv False
# 2019-12-06 C.csv True
# 2019-12-06 CFG.csv True
# 2019-12-06 CTXS.csv True
# 2019-12-06 CME.csv True
# 2019-12-06 CMS.csv False
# 2019-12-06 KO.csv True
# 2019-12-06 CTSH.csv False
# 2019-12-06 CL.csv False
# 2019-12-06 CMCSA.csv True
# 2019-12-06 CMA.csv True
# 2019-12-06 CAG.csv True
# 2019-12-06 CXO.csv True
# 2019-12-06 COP.csv True
# 2019-12-06 ED.csv True
# 2019-12-06 STZ.csv False
# 2019-12-06 GLW.csv False
# 2019-12-06 COST.csv True
# 2019-12-06 COTY.csv False
# 2019-12-06 CCI.csv False
# 2018-04-04 CSRA.csv False
# 2019-12-06 CSX.csv False
# 2019-12-06 CMI.csv True
# 2019-12-06 CVS.csv True
# 2019-12-06 DHI.csv True
# 2019-12-06 DHR.csv False
# 2019-12-06 DRI.csv True
# 2019-12-06 DVA.csv True
# 2019-12-06 DE.csv True
# 2019-12-06 DAL.csv True
# 2019-12-06 XRAY.csv False
# 2019-12-06 DVN.csv True
# 2019-12-06 DLR.csv False
# 2019-12-06 DFS.csv False
# 2019-12-06 DISCA.csv True
# 2019-12-06 DISCK.csv True
# 2019-12-06 DISH.csv True
# 2019-12-06 DG.csv False
# 2019-12-06 DLTR.csv True
# 2019-12-06 D.csv True
# 2019-12-06 DOV.csv False
# 2019-05-31 DWDP.csv True
# 2018-07-09 DPS.csv True
# 2019-12-06 DTE.csv False
# 2019-12-06 DUK.csv True
# 2019-12-06 DRE.csv True
# 2019-12-06 DXC.csv True
# 2019-12-06 ETFC.csv True
# 2019-12-06 EMN.csv True
# 2019-12-06 ETN.csv False
# 2019-12-06 EBAY.csv False
# 2019-12-06 ECL.csv False
# 2019-12-06 EIX.csv True
# 2019-12-06 EW.csv True
# 2019-12-06 EA.csv True
# 2019-12-06 EMR.csv False
# 2019-12-06 ETR.csv False
# 2018-11-06 EVHC.csv True
# 2019-12-06 EOG.csv True
# 2019-12-06 EQT.csv True
# 2019-12-06 EFX.csv False
# 2019-12-06 EQIX.csv False
# 2019-12-06 EQR.csv False
# 2019-12-06 ESS.csv False
# 2019-12-06 EL.csv False
# 2019-12-06 RE.csv True
# 2019-12-06 ES.csv True
# 2019-12-06 EXC.csv False
# 2019-12-06 EXPE.csv False
# 2019-12-06 EXPD.csv False
# 2018-12-20 ESRX.csv True
# 2019-12-06 EXR.csv False
# 2019-12-06 XOM.csv True
# 2019-12-06 FFIV.csv True
# 2019-12-06 FB.csv True
# 2019-12-06 FAST.csv False
# 2019-12-06 FRT.csv False
# 2019-12-06 FDX.csv False
# 2019-12-06 FIS.csv True
# 2019-12-06 FITB.csv True
# 2019-12-06 FE.csv True
# 2019-12-06 FISV.csv True
# 2019-12-06 FLIR.csv False
# 2019-12-06 FLS.csv False
# 2019-12-06 FLR.csv True
# 2019-12-06 FMC.csv False
# 2019-12-06 FL.csv True
# 2019-12-06 F.csv True
# 2019-12-06 FTV.csv False
# 2019-12-06 FBHS.csv False
# 2019-12-06 BEN.csv True
# 2019-12-06 FCX.csv True
# 2019-12-06 GPS.csv True
# 2019-12-06 GRMN.csv True
# 2019-12-06 IT.csv False
# 2019-12-06 GD.csv True
# 2019-12-06 GE.csv True
# 2018-08-28 GGP.csv True
# 2019-12-06 GIS.csv True
# 2019-12-06 GM.csv True
# 2019-12-06 GPC.csv False
# 2019-12-06 GILD.csv True
# 2019-12-06 GPN.csv True
# 2019-12-06 GS.csv True
# 2019-12-06 GT.csv True
# 2019-12-06 GWW.csv True
# 2019-12-06 HAL.csv True
# 2019-12-06 HBI.csv False
# 2019-12-06 HOG.csv True
# 2019-12-06 HRS.csv False
# 2019-12-06 HIG.csv False
# 2019-12-06 HAS.csv True
# 2019-12-06 HCA.csv False
# 2019-12-06 HCP.csv True
# 2019-12-06 HP.csv True
# 2019-12-06 HSIC.csv True
# 2019-12-06 HES.csv True
# 2019-12-06 HPE.csv False
# 2019-12-06 HLT.csv False
# 2019-12-06 HOLX.csv True
# 2019-12-06 HD.csv False
# 2019-12-06 HON.csv False
# 2019-12-06 HRL.csv True
# 2019-12-06 HST.csv False
# 2019-12-06 HPQ.csv False
# 2019-12-06 HUM.csv True
# 2019-12-06 HBAN.csv True
# 2019-12-06 HII.csv False
# 2019-12-06 IDXX.csv True
# 2019-12-06 INFO.csv False
# 2019-12-06 ITW.csv False
# 2019-12-06 ILMN.csv True
# 2019-12-06 INCY.csv True
# 2019-12-06 IR.csv False
# 2019-12-06 INTC.csv True
# 2019-12-06 ICE.csv True
# 2019-12-06 IBM.csv False
# 2019-12-06 IP.csv True
# 2019-12-06 IPG.csv True
# 2019-12-06 IFF.csv True
# 2019-12-06 INTU.csv False
# 2019-12-06 ISRG.csv True
# 2019-12-06 IVZ.csv True
# 2019-12-06 IPGP.csv False
# 2019-12-06 IQV.csv True
# 2019-12-06 IRM.csv True
# 2019-12-06 JBHT.csv False
# 2019-12-06 JEC.csv False
# 2019-12-06 SJM.csv True
# 2019-12-06 JNJ.csv True
# 2019-12-06 JCI.csv False
# 2019-12-06 JPM.csv True
# 2019-12-06 JNPR.csv True
# 2019-12-06 KSU.csv True
# 2019-12-06 K.csv True
# 2019-12-06 KEY.csv True
# 2019-12-06 KMB.csv True
# 2019-12-06 KIM.csv False
# 2019-12-06 KMI.csv False
# 2019-12-06 KLAC.csv True
# 2019-12-06 KSS.csv True
# 2019-12-06 KHC.csv True
# 2019-12-06 KR.csv True
# 2019-12-06 LB.csv True
# 2019-06-28 LLL.csv True
# 2019-12-06 LH.csv False
# 2019-12-06 LRCX.csv False
# 2019-12-06 LEG.csv False
# 2019-12-06 LEN.csv False
# 2018-05-23 LUK.csv True
# 2019-12-06 LLY.csv True
# 2019-12-06 LNC.csv True
# 2019-12-06 LKQ.csv True
# 2019-12-06 LMT.csv False
# 2019-12-06 L.csv True
# 2019-12-06 LOW.csv True
# 2019-12-06 LYB.csv True
# 2019-12-06 MTB.csv True
# 2019-12-06 MAC.csv True
# 2019-12-06 M.csv True
# 2019-12-06 MRO.csv True
# 2019-12-06 MPC.csv True
# 2019-12-06 MAR.csv False
# 2019-12-06 MMC.csv False
# 2019-12-06 MLM.csv True
# 2019-12-06 MAS.csv False
# 2019-12-06 MA.csv False
# 2019-12-06 MAT.csv True
# 2019-12-06 MKC.csv True
# 2019-12-06 MCD.csv True
# 2019-12-06 MCK.csv True
# 2019-12-06 MDT.csv False
# 2019-12-06 MRK.csv True
# 2019-12-06 MET.csv True
# 2019-12-06 MTD.csv False
# 2019-12-06 MGM.csv True
# 2019-12-06 KORS.csv True
# 2019-12-06 MCHP.csv False
# 2019-12-06 MU.csv True
# 2019-12-06 MSFT.csv True
# 2019-12-06 MAA.csv True
# 2019-12-06 MHK.csv True
# 2019-12-06 TAP.csv True
# 2019-12-06 MDLZ.csv False
# 2018-06-08 MON.csv True
# 2019-12-06 MNST.csv False
# 2019-12-06 MCO.csv False
# 2019-12-06 MS.csv True
# 2019-12-06 MSI.csv False
# 2019-12-06 MYL.csv True
# 2019-12-06 NDAQ.csv False
# 2019-12-06 NOV.csv True
# 2019-12-06 NAVI.csv True
# 2019-12-06 NKTR.csv True
# 2019-12-06 NTAP.csv True
# 2019-12-06 NFLX.csv True
# 2019-12-06 NWL.csv True
# 2019-02-14 NFX.csv False
# 2019-12-06 NEM.csv True
# 2019-12-06 NWSA.csv True
# 2019-12-06 NWS.csv True
# 2019-12-06 NEE.csv True
# 2019-12-06 NLSN.csv True
# 2019-12-06 NKE.csv False
# 2019-12-06 NI.csv True
# 2019-12-06 NBL.csv True
# 2019-12-06 JWN.csv True
# 2019-12-06 NSC.csv False
# 2019-12-06 NTRS.csv True
# 2019-12-06 NOC.csv False
# 2019-12-06 NCLH.csv False
# 2019-12-06 NRG.csv True
# 2019-12-06 NUE.csv True
# 2019-12-06 NVDA.csv True
# 2019-12-06 ORLY.csv False
# 2019-12-06 OXY.csv True
# 2019-12-06 OMC.csv True
# 2019-12-06 OKE.csv False
# 2019-12-06 ORCL.csv False
# 2019-12-06 PCAR.csv False
# 2019-12-06 PKG.csv True
# 2019-12-06 PH.csv False
# 2019-12-06 PAYX.csv False
# 2019-12-06 PYPL.csv True
# 2019-12-06 PNR.csv True
# 2019-12-06 PBCT.csv True
# 2019-12-06 PEP.csv False
# 2019-12-06 PKI.csv False
# 2019-12-06 PRGO.csv True
# 2019-12-06 PFE.csv True
# 2019-12-06 PCG.csv True
# 2019-12-06 PM.csv False
# 2019-12-06 PSX.csv True
# 2019-12-06 PNW.csv False
# 2019-12-06 PXD.csv True
# 2019-12-06 PNC.csv True
# 2019-12-06 RL.csv True
# 2019-12-06 PPG.csv True
# 2019-12-06 PPL.csv True
# 2018-10-30 PX.csv True
# 2019-12-06 PFG.csv True
# 2019-12-06 PG.csv False
# 2019-12-06 PGR.csv False
# 2019-12-06 PLD.csv False
# 2019-12-06 PRU.csv True
# 2019-12-06 PEG.csv False
# 2019-12-06 PSA.csv False
# 2019-12-06 PHM.csv True
# 2019-12-06 PVH.csv True
# 2019-12-06 QRVO.csv True
# 2019-12-06 QCOM.csv True
# 2019-12-06 PWR.csv True
# 2019-12-06 DGX.csv True
# 2019-12-06 RRC.csv True
# 2019-12-06 RJF.csv True
# 2019-12-06 RTN.csv False
# 2019-12-06 O.csv False
# 2019-07-08 RHT.csv True
# 2019-12-06 REG.csv False
# 2019-12-06 REGN.csv True
# 2019-12-06 RF.csv True
# 2019-12-06 RSG.csv True
# 2019-12-06 RMD.csv True
# 2019-12-06 RHI.csv True
# 2019-12-06 ROK.csv True
# 2018-11-26 COL.csv True
# 2019-12-06 ROP.csv False
# 2019-12-06 ROST.csv True
# 2019-12-06 RCL.csv True
# 2019-12-06 SPGI.csv True
# 2019-12-06 CRM.csv True
# 2019-12-06 SBAC.csv False
# 2018-12-31 SCG.csv True
# 2019-12-06 SLB.csv True
# 2019-12-06 STX.csv False
# 2019-12-06 SEE.csv False
# 2019-12-06 SRE.csv True
# 2019-12-06 SHW.csv False
# 2019-12-06 SPG.csv False
# 2019-12-06 SWKS.csv False
# 2019-12-06 SLG.csv True
# 2019-12-06 SNA.csv True
# 2019-12-06 SO.csv False
# 2019-12-06 LUV.csv False
# 2019-12-06 SWK.csv True
# 2019-12-06 SBUX.csv False
# 2019-12-06 STT.csv True
# 2019-12-06 SRCL.csv False
# 2019-12-06 SYK.csv False
# 2019-12-06 STI.csv True
# 2019-12-06 SIVB.csv True
# 2019-12-06 SYMC.csv False
# 2019-12-06 SYF.csv False
# 2019-12-06 SNPS.csv False
# 2019-12-06 SYY.csv False
# 2019-12-06 TROW.csv True
# 2019-12-06 TTWO.csv True
# 2019-12-06 TPR.csv True
# 2019-12-06 TGT.csv True
# 2019-12-06 TEL.csv True
# 2019-12-06 FTI.csv True
# 2019-12-06 TXN.csv True
# 2019-12-06 TXT.csv False
# 2019-12-06 BK.csv True
# 2019-12-06 CLX.csv True
# 2019-12-06 COO.csv True
# 2019-12-06 HSY.csv True
# 2019-12-06 MOS.csv True
# 2019-12-06 TRV.csv False
# 2019-12-06 DIS.csv True
# 2019-12-06 TMO.csv True
# 2019-12-06 TIF.csv True
# 2018-06-15 TWX.csv True
# 2019-12-06 TJX.csv True
# 2019-12-06 TMK.csv True
# 2019-09-17 TSS.csv True
# 2019-12-06 TSCO.csv True
# 2019-12-06 TDG.csv False
# 2019-12-06 TRIP.csv True
# FOXA.csv  :  Cannot feed value of shape (1, 0, 5) for Tensor 'Placeholder:0', which has shape '(?, 20, 5)'
